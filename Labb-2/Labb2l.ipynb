# %% [markdown]
# ## Labb 1
#
# - Skapa en maskininlärningsalgoritm för att klassificera och labela om det är pichu eller pickachu baserat på längd och bredd
# - Skicka in en matplotlib för att plotta datapunkterna (färlägga efter vilken pokemon det är i röd eller blå)

# %%
## Strategi 
#- Vi vill skicka in datapoints texten och snygga till den. Den ska se ut liknande detta:

#Sample with (width, height): (25, 32) classified as Pikachu
#Sample with (width, height): (24.2, 31.5) classified as Pikachu 
#Sample with (width, height): (22, 34) classified as Pikachu
#Sample with (width, height): (20.5, 34) classified as Pichu

#- Vi vill splitta vilka som har blivit labelade 1 eller 0 i varsina listor
#(", 0")
#(", 1")

# %%
## Importar olika verktyg vi kommer jobba med

import matplotlib.pyplot as plt
import re
import numpy as np


# Imports data point file
datapoints = "../Data1/datapoints (3).txt"
#datapoints1 = "../Data1/datapoints (3)_tmp.txt"

with open(datapoints, "r") as f_read: #open(datapoints1, "w") as f_write:
    lines = f_read.readlines()

lines.pop(0)

pokemon_width = []
pokemon_height = []

for line in lines:
    line = re.sub('[ \n]', '', line)
print(line)


plt.xlabel("Pokemon_Width")
plt.ylabel("Pokemon_Height")
plt.grid()
# Out:
# 22.30210323807139,32.73237945145149,0
